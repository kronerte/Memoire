# %% [markdown]
# # Introduction about the anomaly package

# %% [markdown]
# In this jupyter notebook, I will explain the major concept of the Anomaly Detection using Mean Max Descrepency

# %% [markdown]
# ## First import the package

# %%
import os
os.chdir('..')
import Anomaly

# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
from seaborn import kdeplot

# %%
importlib.reload(Anomaly)
# Out:
# <module 'Anomaly' from '/home/kronert/Documents/Python/Mémoire/Memoire/Anomaly/__init__.py'>

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Characteristic Kernels

# %%
x = np.r_[-3:3:1000j].reshape((1000,1))
for sigma in [0.2,0.5,1,2,4]:
    plt.plot(x,Anomaly.kernels.Gaussian(np.sqrt(sigma))(x,0),label=f"sigma={sigma}")
plt.legend()
plt.title("Gaussian kernel")
#plt.savefig("gaussian_kernel.eps")
# Out:
# Text(0.5, 1.0, 'Gaussian kernel')

# %%
x = np.r_[-3:3:1000j].reshape((1000,1))
for sigma in [0.2,0.5,1,2,4]:
    plt.plot(Anomaly.kernels.Laplacian(sigma)(x,0),label=f"beta={sigma}")
plt.legend()
plt.title("laplacian kernel")
#plt.savefig("laplacian_kernel.eps")
# Out:
# Text(0.5, 1.0, 'laplacian kernel')

# %%
for t in [0,0.1,0.3,0.5,0.7,0.9,1]:
    kernel = Anomaly.kernels.CCK([Anomaly.kernels.Gaussian(1),Anomaly.kernels.Laplacian(1)],[t,1-t])
    plt.plot(kernel(x,0),label=f"t={t}")
plt.legend()
plt.title("Convex Combination")
#plt.savefig("convex.eps")
# Out:
# Text(0.5, 1.0, 'Convex Combination')

# %% [markdown]
# ## MMD

# %%
law_p = Anomaly.utils.normal(0,1)
law_q = Anomaly.utils.normal(1,1)

# %%
kdeplot(law_p(10000).ravel(),label = "distribution under normal conditions")
kdeplot(law_q(10000).ravel(),label = "distribution under anormal conditions")

# %%
MMD = Anomaly.MMD.QMMD
kernel = Anomaly.kernels.Gaussian(1)

# %time sample = Anomaly.estimators.sampleMMD_MC(MMD, kernel, law_p, law_q, 100, 100, finalSampleSize=1000)

kdeplot(sample,label = "distribution Quadratic MMD Estimator")
# Out:
# CPU times: user 10.9 s, sys: 1.15 s, total: 12.1 shevé % achevé % achevé % achevé % achevé
# Wall time: 11.1 s

# %%
MMD = Anomaly.MMD.LMMD
kernel = Anomaly.kernels.Gaussian(1)

# %time sample = Anomaly.estimators.sampleMMD_MC(MMD, kernel, law_p, law_q, 100, 100, finalSampleSize=1000)

kdeplot(sample,label = "distribution Linear MMD Estimator")
# Out:
# CPU times: user 3.6 s, sys: 448 ms, total: 4.04 schevé % achevé % achevé % achevé % achevé% achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé % achevé% achevé % achevé % achevé % achevé % achevé
# Wall time: 4.02 s

# %%
MMD = Anomaly.MMD.OMMD
kernel = Anomaly.kernels.Gaussian(1)

# %time sample = Anomaly.estimators.sampleMMD_MC(MMD, kernel, law_p, law_q, 100, 100, finalSampleSize=1000)

kdeplot(sample,label = "distribution Online MMD Estimator")
# Out:
# CPU times: user 23.4 s, sys: 851 ms, total: 24.3 sevé % achevé % achevé % achevé % achevé
# Wall time: 24 s
